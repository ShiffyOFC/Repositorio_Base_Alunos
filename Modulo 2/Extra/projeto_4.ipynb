# %% [markdown]
# # 🕵️‍♂️ MISSÃO SINARM: ANÁLISE DE INTELIGÊNCIA
# ## 📋 CONTEXTO DA OPERAÇÃO
#
# Caros Aspirantes a Analistas de Dados Forenses,
#
# Vocês foram recrutados para uma operação especial da Polícia Federal! Como estagiários do setor de inteligência, sua missão é analisar dados reais de ocorrências envolvendo armas de fogo.
#
# ### Um arquivo confidencial contendo dados de 2025 acaba de chegar em suas mãos: OCORRENCIAS_2025.csv
# ---
# ## 🎯 OBJETIVO DA MISSÃO
#
# Sua tarefa é desenvolver um algoritmo em Python que:
#
#     Identifique os tipos de armas (espécies) envolvidas nas ocorrências
#
#     Classifique as armas em categorias específicas (calibres)
#
#     Conte quantas armas de cada tipo foram apreendidas
#
# ## 🔍 DADOS DA OPERAÇÃO
#
# O arquivo CSV contém as seguintes colunas relevantes:
#
#     ESPECIE_ARMA (descrição do tipo de arma)
#
#     CALIBRE_ARMA (calibre da arma)
#
#     MARCA_ARMA (fabricante da arma)

# %%
# Seu código aqui:

import csv

applesFile = open('OCORRENCIAS_2025.csv')
applesReader = csv.reader(applesFile, delimiter=';')
"""applesData = list(applesReader)
applesData


print(applesData[2][6])"""
Espingarda = 0
Garruchao = 0
Pistola = 0
Pistolao = 0
Carabina = 0
Rifle = 0
Revolver = 0
Fuzil = 0
Garrucha = 0

print("Tipos de armas envolvidas em crimes foram: ", "\n{Pistola, Pistolão, Espingarda,\nCarabina, Rifle, Fuzil, \nRevolver ,Garrucha, Garruchão}\n")

for row in applesReader:
    if row[4].strip() == 'Pistolao':
        Pistolao+=1
    if row[4].strip() == 'Espingarda':
        Espingarda+=1
    if row[4].strip() == 'Pistola':
        Pistola+=1
    if row[4].strip() == 'Garrucha':
        Garrucha+=1
    if row[4].strip() == 'Rifle':
        Rifle+=1
    if row[4].strip() == 'Fuzil':
        Fuzil+=1
    if row[4].strip() == 'Garruchao':
        Garruchao+=1
    if row[4].strip() == 'Revolver':
        Revolver+=1
    if row[4].strip() == 'Carabina':
        Carabina+=1

print("Quantidade de armas envolvidas (Separadas por tipo):\n\nPistolão: ", Pistolao,"\n\nEspingarda: ", Espingarda,"\n\nPistola: ", Pistola,"\n\nGarrucha: ", Garrucha,"\n\nRifle: ", Rifle,"\n\nGarruchão: ", Garruchao,"\n\nRevolver: ", Revolver,"\n\nCarabina: ", Carabina,"\n\nFuzil: ", Fuzil)
# Armas feito
# Out:
# Tipos de armas envolvidas em crimes foram:
# {Pistola, Pistolão, Espingarda,
# Carabina, Rifle, Fuzil,
# Revolver ,Garrucha, Garruchão}
#
# Quantidade de armas envolvidas (Separadas por tipo):
#
# Pistolão:  10
#
# Espingarda:  1099
#
# Pistola:  3120
#
# Garrucha:  12
#
# Rifle:  495
#
# Garruchão:  2
#
# Revolver:  1750
#
# Carabina:  200
#
# Fuzil:  10
